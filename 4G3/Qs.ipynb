# %%
import models.network as network
import seaborn as sns
sns.set()
sns.set_context("poster")
import numpy as np

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ### Question 1 & 2

# %%
test_net = network.Network(N=1000, K=1, weights=np.array([[0,0,0.9],[0,0,0]]))
# Out:
# 3000.0
# 3000.0

# %%
test_net.x_pop.sample_activity(2, True)
# Out:
# Average firing rate: 10.0615
# True firing rate: 10

# %% [markdown]
# ### Question 2

# %%
test_net.simulate(t=2, plot=True, reset=True)
# Out:
# Average firing rate: 14.0
# True firing rate: 10
# 100%|██████████| 19998/19998 [00:01<00:00, 13778.04it/s]
# Average firing rate: 4.5
# True firing rate: 10
# Estimated mean: 0.14283640135756562
#  Estimated variance: 0.05477280983515888

# %% [markdown]
# ### Question 3

# %%
test_net = network.Network(N=100, K=100, weights=np.array([[0,0,1],[0,0,0]]))
# Out:
# 30000.0

# %%
test_net.simulate(t=10, plot=True, reset=True)
# Out:
# Average firing rate: 9.896
# True firing rate: 10
# 100%|██████████| 99998/99998 [04:49<00:00, 344.86it/s]
# Average firing rate: 0.0
# True firing rate: 10
# Estimated mean: 0.19812243460295673
#  Estimated variance: 0.000894266475712879

# %%
test_net = network.Network(N=1000, K=1000, weights=np.array([[0,0,1],[0,0,0]]))
# Out:
# 3000000.0

# %%
test_net.simulate(t=10, plot=True, reset=True)
# Out:
# Average firing rate: 9.9882
# True firing rate: 10
# 100%|██████████| 99998/99998 [1:03:58<00:00, 26.05it/s]
# Average firing rate: 0.0
# True firing rate: 10
# Estimated mean: 0.19968742972118247
#  Estimated variance: 0.00011173445012443348

# %%
test_net = network.Network(N=10, K=10, weights=np.array([[0,0,1],[0,0,0]]))
# Out:
# 300.0

# %%
test_net.simulate(t=10, plot=True, reset=True)
# Out:
# Average firing rate: 10.5
# True firing rate: 10
# 100%|██████████| 99998/99998 [00:32<00:00, 3063.01it/s]
# Average firing rate: 0.0
# True firing rate: 10
# Estimated mean: 0.20915393362834211
#  Estimated variance: 0.01049206500414745
#  Estimated Fano factor: 9989.428571428565

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(20,10))
x = np.array(list(range(0,1000)))
y = (0.999 * 4e-3 / 3.99e-2)/x
plt.plot(x,y)
#plt.ylim([0,0.1])
plt.yscale("log")
plt.xscale("log")
plt.scatter([1,10,100,1000], [0.0991 ,0.01049, 0.0008942, 0.0001117], color='r')
plt.ylabel(r"$\sigma^{2}$")
plt.xlabel(r"$K$")
plt.savefig("meanvarplot.png", dpi=300, bbox_inches='tight')
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:4: RuntimeWarning: divide by zero encountered in true_divide
#   after removing the cwd from sys.path.

# %%
test_net = network.Network(N=1, K=1, weights=np.array([[0,0,1],[0,0,0]]))
# Out:
# 3.0
# 3.0

# %%
test_net.simulate(t=10, plot=True, reset=False)
# Out:
# Average firing rate: 9.7
# True firing rate: 10
# 100%|██████████| 99998/99998 [00:13<00:00, 7489.88it/s]
# Average firing rate (E): 280.6
# Average firing rate (I): 0.0
# True firing rate: 10
# Estimated mean: 0.19301096399885703
#  Estimated variance: 0.09908975013824142
#  Estimated Fano factor: 113.94107478517724

# %% [markdown]
# ### Question 4

# %%
test_net = network.Network(N=200, K=200, weights=np.array([[0,0,2],[0,0,0]]))
# Out:
# 120000.0
# 120000.0

# %%
test_net.simulate(t=2, plot=True, reset=True, multip=True, full=False)
# Out:
# Average firing rate: 9.975
# True firing rate: 10
# 100%|██████████| 19998/19998 [00:55<00:00, 360.63it/s]
# Average firing rate (E): 9.0
# Average firing rate (I): 0.0
# True firing rate: 10
# Estimated mean: -0.23855193216296072
#  Estimated variance: 0.3481243911036511
#  Estimated Fano factor: 0.7614379084967319

# %% [markdown]
# ### Question 5

# %%
test_net_full = network.Network(N=1000, K=100, weights=np.array([[1,-2,1],[1,-1.8,0.8]]), rx=20)
# Out:
# 300000.0
# 300000.0

# %%
test_net_full.simulate(t=2, plot=True, reset=True, multip=False, full=True)
# Out:
# Average firing rate: 20.183500000000002
# True firing rate: 20
# 100%|██████████| 19998/19998 [37:15<00:00,  8.95it/s]
# Average firing rate (E): 24.1755
# Average firing rate (I): 22.487000000000002
# True firing rate: 20
# Estimated mean: -0.7807047922699475
#  Estimated variance: 0.8608513969375848
#  Estimated Fano factor: 1.4166666666666667

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(20,10))
plt.plot([5,10,15,20], [6.98, 13.07, 18.31, 24.18])
plt.plot([5,10,15,20], [5.88, 11.73, 16.80, 22.49])
plt.ylabel(r"$r_{E,I}$")
plt.xlabel(r"$r_{X}$")
plt.savefig("rxvar.png", dpi=300, bbox_inches='tight')
