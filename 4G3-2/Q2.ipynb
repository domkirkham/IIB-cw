# %%
from hodhux import Neuron
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
sns.set_context("poster")

# %%
hh = Neuron()

# %%
hh.simulate_1(i_ext=np.arange(7, 8, 1), plot=True)
# Out:
# I_ext = 7
# m(0): 0.05293248525724958
#  n(0): 0.3176769140606974
#  h(0): 0.5961207535084603

# %%
hh.simulate_1(i_ext=np.arange(2.2, 2.3, 0.01), plot=True)
# Out:
# I_ext = 2.2
# m(0): 0.05293248525724958
#  n(0): 0.3176769140606974
#  h(0): 0.5961207535084603
# I_ext = 2.21
# m(0): 0.05293248525724958
#  n(0): 0.3176769140606974
#  h(0): 0.5961207535084603
# I_ext = 2.2199999999999998
# m(0): 0.05293248525724958
#  n(0): 0.3176769140606974
#  h(0): 0.5961207535084603
# I_ext = 2.2299999999999995
# m(0): 0.05293248525724958
#  n(0): 0.3176769140606974
#  h(0): 0.5961207535084603
# I_ext = 2.2399999999999993
# m(0): 0.05293248525724958
#  n(0): 0.3176769140606974
#  h(0): 0.5961207535084603
# I_ext = 2.249999999999999
# m(0): 0.05293248525724958
#  n(0): 0.3176769140606974
#  h(0): 0.5961207535084603
# I_ext = 2.259999999999999
# m(0): 0.05293248525724958
#  n(0): 0.3176769140606974
#  h(0): 0.5961207535084603
# I_ext = 2.2699999999999987
# m(0): 0.05293248525724958
#  n(0): 0.3176769140606974
#  h(0): 0.5961207535084603
# I_ext = 2.2799999999999985
# m(0): 0.05293248525724958
#  n(0): 0.3176769140606974
#  h(0): 0.5961207535084603
# ...

# %%
hh.simulate_2(I=10)
